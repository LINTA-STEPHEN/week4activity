# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Admin\Telco-Customer-Churn.csv')
print(df)                                               #calling csv file to jupyter notebook
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.countplot(x='gender',data=df,hue='Churn')
plt.title("Churn count vs Gender ")           #graph showing the churn count vs gender.
# Out:
# Text(0.5, 1.0, 'Churn count vs Gender ')

# %%
df.SeniorCitizen.value_counts()
# Out:
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64

# %%
df[(df['gender']=='Female')&(df['SeniorCitizen']==1.0)]['SeniorCitizen'].count() #counting the value of female senior citizens.
# Out:
# 568

# %%
sns.scatterplot(data=df,x='tenure',y='TotalCharges')
plt.title("Tenure vs Total Charges")     #graph showing tenure vs total charges
# Out:
# Text(0.5, 1.0, 'Tenure vs Total Charges')

# %%
df.Contract.value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Contract, dtype: int64

# %%
dfS = df[df['SeniorCitizen']==1.0]
sns.countplot(x ='Contract', data = dfS, color = 'green', alpha = 0.3)
plt.title("Contracts preferred by Senior Citizens")   #showing the contract prefered by senior citizens.
# Out:
# Text(0.5, 1.0, 'Contracts preferred by Senior Citizens')

# %% [markdown]
# most of the senior citizens are choosing month to month contract.

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
sns.histplot(y ='PaymentMethod', data =df ,stat = 'percent' )
plt.ylabel(" ")
plt.title("Payment methods Percentage")
# Out:
# Text(0.5, 1.0, 'Payment methods Percentage')

# %% [markdown]
# most of the payments methods are done by electronic check.
